# %%
import pandas as pd

# %%
from data_extraction import DataExtractor
from data_cleaning import DataCleaning

# %%
extractor = DataExtractor()
cleaning = DataCleaning()

# %%
extractor = DataExtractor()

print(extractor.retrieve_pdf_data(pdf_link='https://data-handling-public.s3.eu-west-1.amazonaws.com/card_details.pdf'))
# Out:
#             card_number expiry_date                card_provider  \
# 0        30060773296197       09/26  Diners Club / Carte Blanche
# 1       349624180933183       10/23             American Express
# 2      3529023891650490       06/23                 JCB 16 digit
# 3       213142929492281       09/27                 JCB 15 digit
# 4          502067329974       10/25                      Maestro
# ...                 ...         ...                          ...
# 15304   180036921556789       12/28                 JCB 15 digit
# 15305   180018030448512       11/24                 JCB 15 digit
# 15306  3569953313547220       04/24                 JCB 16 digit
# 15307  4444521712606810       06/27                VISA 16 digit
# 15308   372031786522735       02/30             American Express
#
#       date_payment_confirmed
# 0                 2015-11-25
# 1                 2001-06-18
# 2                 2000-12-26
# 3                 2011-02-12
# 4                 1997-03-13
# ...

# %%
df = pd.DataFrame(extractor.retrieve_pdf_data(pdf_link='https://data-handling-public.s3.eu-west-1.amazonaws.com/card_details.pdf'))
pd.set_option('display.max_rows', None)

print(df)
# Out:
#                   card_number expiry_date                card_provider  \
# 0              30060773296197       09/26  Diners Club / Carte Blanche
# 1             349624180933183       10/23             American Express
# 2            3529023891650490       06/23                 JCB 16 digit
# 3             213142929492281       09/27                 JCB 15 digit
# 4                502067329974       10/25                      Maestro
# 5            3506661913512980       11/23                 JCB 16 digit
# 6             377549437870679       07/27             American Express
# 7            2321541881278150       02/29                   Mastercard
# 8            6011037917693140       02/24                     Discover
# 9                502049986008       07/23                      Maestro
# 10           6501622116456490       10/28                     Discover
# 11           6502495513721380       11/27                     Discover
# ...

# %%
current_date = pd.to_datetime('today')
print(current_date)
# Out:
# 2024-09-21 15:23:28.212331

# %%
extractor = DataExtractor()

df = pd.DataFrame(extractor.retrieve_stores_data(endpoint="https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/{store_number}"))
# Out:
# <Response [200]>
# {'index': 0, 'address': 'N/A', 'longitude': 'N/A', 'lat': 'N/A', 'locality': 'N/A', 'store_code': 'WEB-1388012W', 'staff_numbers': '325', 'opening_date': '2010-06-12', 'store_type': 'Web Portal', 'latitude': None, 'country_code': 'GB', 'continent': 'Europe'}
# <Response [200]>
# {'index': 1, 'address': 'Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe', 'longitude': '51.62907', 'lat': None, 'locality': 'High Wycombe', 'store_code': 'HI-9B97EE4E', 'staff_numbers': '34', 'opening_date': '1996-10-25', 'store_type': 'Local', 'latitude': '-0.74934', 'country_code': 'GB', 'continent': 'Europe'}
# <Response [200]>
# {'index': 2, 'address': 'Heckerstraße 4/5\n50491 Säckingen, Landshut', 'longitude': '48.52961', 'lat': None, 'locality': 'Landshut', 'store_code': 'LA-0772C7B9', 'staff_numbers': '92', 'opening_date': '2013-04-12', 'store_type': 'Super Store', 'latitude': '12.16179', 'country_code': 'DE', 'continent': 'Europe'}
# <Response [200]>
# ...

# %%
cleaning = DataCleaning()

raw_store_df = extractor.retrieve_stores_data(endpoint="https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/{store_number}")

print(cleaning.clean_store_data(raw_store_df))
# Out:
# <Response [200]>
# {'index': 0, 'address': 'N/A', 'longitude': 'N/A', 'lat': 'N/A', 'locality': 'N/A', 'store_code': 'WEB-1388012W', 'staff_numbers': '325', 'opening_date': '2010-06-12', 'store_type': 'Web Portal', 'latitude': None, 'country_code': 'GB', 'continent': 'Europe'}
# <Response [200]>
# {'index': 1, 'address': 'Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, High Wycombe', 'longitude': '51.62907', 'lat': None, 'locality': 'High Wycombe', 'store_code': 'HI-9B97EE4E', 'staff_numbers': '34', 'opening_date': '1996-10-25', 'store_type': 'Local', 'latitude': '-0.74934', 'country_code': 'GB', 'continent': 'Europe'}
# <Response [200]>
# {'index': 2, 'address': 'Heckerstraße 4/5\n50491 Säckingen, Landshut', 'longitude': '48.52961', 'lat': None, 'locality': 'Landshut', 'store_code': 'LA-0772C7B9', 'staff_numbers': '92', 'opening_date': '2013-04-12', 'store_type': 'Super Store', 'latitude': '12.16179', 'country_code': 'DE', 'continent': 'Europe'}
# <Response [200]>
# ...

# %%
print(cleaning.clean_store_data(raw_store_df).columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Index(['index', 'address', 'longitude', 'locality', 'store_code',
#        'staff_numbers', 'opening_date', 'store_type', 'latitude',
#        'country_code', 'continent'],
#       dtype='object')

# %%
print(raw_store_df.iloc[:218])
# Out:
#      index                                            address longitude   lat  \
# 0        0                                                N/A       N/A   N/A
# 1        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907  None
# 2        2        Heckerstraße 4/5\n50491 Säckingen, Landshut  48.52961  None
# 3        3  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury     51.26  None
# 4        4  Studio 6\nStephen landing\nSouth Simon\nB77 2W...   53.0233  None
# ..     ...                                                ...       ...   ...
# 213    213  303 Abdul cliffs\nSandersmouth\nNR18 5HB, Poul...  53.83333  None
# 214    214  Flat 81\nGardner mission\nNorth Leighton\nZE25...  50.76306  None
# 215    215          Tina-Döring-Gasse 68\n95518 Calw, Gauting  48.06919  None
# 216    216  Flat 75b\nRobert courts\nAdamsstad\nPA4B 9HF, ...     51.26  None
# 217    217                                               NULL      NULL  NULL
#
# ...

# %%
clean_df = cleaning.clean_store_data(raw_store_df)

clean_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 clean_df = cleaning.clean_store_data(raw_store_df)
#       3 clean_df
#
# NameError: name 'raw_store_df' is not defined

# %%
print(clean_df.iloc[:218])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(clean_df.iloc[:218])
#
# NameError: name 'clean_df' is not defined

# %%
clean_df = cleaning.clean_store_data(raw_store_df).to_csv('cleaned_store_data.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
cleaning = DataCleaning()
