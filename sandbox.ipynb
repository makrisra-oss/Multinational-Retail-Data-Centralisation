# %%
import pandas as pd
from pandasgui import show
# Out:
# This process is not trusted! Input event monitoring will not be possible until it is added to accessibility clients.

# %%
df = pd.read_csv("users_table.csv")

# %%
show(df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/65/jy4lt7y15c1bbj4rg1q8nnjh0000gn/T/ipykernel_71906/1525291607.py in ?()
# ----> 1 show(df)
#
# /opt/homebrew/Caskroom/miniconda/base/envs/mrdc/lib/python3.12/site-packages/pandasgui/gui.py in ?(settings, *args, **kwargs)
#     502         logger.warning("Duplicate names were provided, duplicates were ignored.")
#     503
#     504     kwargs = {**kwargs, **items}
#     505
# --> 506     pandas_gui = PandasGui(settings=settings, **kwargs)
#     507     pandas_gui.caller_stack = inspect.currentframe().f_back
#     508
#     509     # Register IPython magic
#
# /opt/homebrew/Caskroom/miniconda/base/envs/mrdc/lib/python3.12/site-packages/pandasgui/gui.py in ?(self, settings, **kwargs)
# ...

# %%
df
# Out:
#        Unnamed: 0  index first_name last_name date_of_birth  \
# 0               0      0   Sigfried     Noack    1990-09-30
# 1               1      1        Guy     Allen    1940-12-01
# 2               2      2      Harry  Lawrence    1995-08-02
# 3               3      3     Darren   Hussain    1972-09-23
# 4               4      4      Garry     Stone    1952-12-20
# ...           ...    ...        ...       ...           ...
# 15315       15315  14913    Stephen   Jenkins    1943-08-09
# 15316       15316  14994    Stephen     Smith    1948-08-20
# 15317       15317  15012    Stephen  Losekann    1940-10-09
# 15318       15318  15269    Stephen    Rivera    1952-06-04
# 15319       15319   1249    Stephen    Duncan    1994-03-27
#
#                             company                 email_address  \
# 0                Heydrich Junitz KG             rudi79@winkler.de
# 1                           Fox Ltd  rhodesclifford@henderson.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15320 entries, 0 to 15319
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     15320 non-null  int64
#  1   index          15320 non-null  int64
#  2   first_name     15299 non-null  object
#  3   last_name      15299 non-null  object
#  4   date_of_birth  15299 non-null  object
#  5   company        15299 non-null  object
#  6   email_address  15299 non-null  object
#  7   address        15299 non-null  object
#  8   country        15299 non-null  object
#  9   country_code   15299 non-null  object
#  10  phone_number   15299 non-null  object
#  11  join_date      15299 non-null  object
#  12  user_uuid      15299 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.5+ MB

# %%
print(df["country_code"].unique())
# Out:
# ['DE' 'GB' 'US' 'VSM4IZ4EL3' nan 'QVUW9JSKY3' 'GGB' '0CU6LW3NKB'
#  'PG8MOC0UZI' 'NTCGYW8LVC' 'FB13AKRI21' 'OS2P9CMHR6' '5D74J6FPFJ'
#  'LZGTB0T5Z7' 'IM8MN1L9MJ' 'RVRFD92E48' 'XKI9UXSCZ1' 'QREF9WLI2A'
#  'XPVCZE2L8B' '44YAIDY048']

# %%
df
# Out:
#        Unnamed: 0  index first_name last_name date_of_birth  \
# 0               0      0   Sigfried     Noack    1990-09-30
# 1               1      1        Guy     Allen    1940-12-01
# 2               2      2      Harry  Lawrence    1995-08-02
# 3               3      3     Darren   Hussain    1972-09-23
# 4               4      4      Garry     Stone    1952-12-20
# ...           ...    ...        ...       ...           ...
# 15315       15315  14913    Stephen   Jenkins    1943-08-09
# 15316       15316  14994    Stephen     Smith    1948-08-20
# 15317       15317  15012    Stephen  Losekann    1940-10-09
# 15318       15318  15269    Stephen    Rivera    1952-06-04
# 15319       15319   1249    Stephen    Duncan    1994-03-27
#
#                             company                 email_address  \
# 0                Heydrich Junitz KG             rudi79@winkler.de
# 1                           Fox Ltd  rhodesclifford@henderson.com
# ...

# %%
from data_cleaning import DataCleaning

cleaning = DataCleaning()
clean_df = cleaning.clean_user_data(df)
print(clean_df)
# Out:
# Unnamed: 0        0
# index             0
# first_name       21
# last_name        21
# date_of_birth    21
# company          21
# email_address    21
# address          21
# country          21
# country_code     21
# phone_number     21
# join_date        21
# user_uuid        21
# dtype: int64
#        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...      ...        ...       ...           ...                           ...
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# ...

# %%
clean_df.to_csv('clean_users_table.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 clean_df.to_csv('clean_users_table.csv')
#
# NameError: name 'clean_df' is not defined

# %%
df['country_code'].unique()
# Out:
# array(['DE', 'GB', 'US', 'VSM4IZ4EL3', nan, 'QVUW9JSKY3', 'GGB',
#        '0CU6LW3NKB', 'PG8MOC0UZI', 'NTCGYW8LVC', 'FB13AKRI21',
#        'OS2P9CMHR6', '5D74J6FPFJ', 'LZGTB0T5Z7', 'IM8MN1L9MJ',
#        'RVRFD92E48', 'XKI9UXSCZ1', 'QREF9WLI2A', 'XPVCZE2L8B',
#        '44YAIDY048'], dtype=object)

# %%
df.drop(df.loc[df['country_code'] > len(2)].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.drop(df.loc[df['country_code'] > 2].index)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mrdc/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mrdc/lib/python3.12/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mrdc/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
# ...

# %%
date_columns = ['date_of_birth', 'join_date']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

df.dropna(subset=['date_of_birth'])
# Out:
#        Unnamed: 0  index first_name last_name date_of_birth  \
# 0               0      0   Sigfried     Noack    1990-09-30
# 1               1      1        Guy     Allen    1940-12-01
# 2               2      2      Harry  Lawrence    1995-08-02
# 3               3      3     Darren   Hussain    1972-09-23
# 4               4      4      Garry     Stone    1952-12-20
# ...           ...    ...        ...       ...           ...
# 15315       15315  14913    Stephen   Jenkins    1943-08-09
# 15316       15316  14994    Stephen     Smith    1948-08-20
# 15317       15317  15012    Stephen  Losekann    1940-10-09
# 15318       15318  15269    Stephen    Rivera    1952-06-04
# 15319       15319   1249    Stephen    Duncan    1994-03-27
#
#                             company                 email_address  \
# 0                Heydrich Junitz KG             rudi79@winkler.de
# 1                           Fox Ltd  rhodesclifford@henderson.com
# ...

# %%
df['date_of_birth'].unique()
# Come back here if this doesn't work
# Out:
# array(['1990-09-30', '1940-12-01', '1995-08-02', ..., '1961-04-24',
#        '1943-08-09', '1994-03-27'], dtype=object)

# %%
example_series = df['country_code'].str.replace('GGB', 'GB')
example_series.unique()
# Out:
# array(['DE', 'GB', 'US', 'VSM4IZ4EL3', nan, 'QVUW9JSKY3', '0CU6LW3NKB',
#        'PG8MOC0UZI', 'NTCGYW8LVC', 'FB13AKRI21', 'OS2P9CMHR6',
#        '5D74J6FPFJ', 'LZGTB0T5Z7', 'IM8MN1L9MJ', 'RVRFD92E48',
#        'XKI9UXSCZ1', 'QREF9WLI2A', 'XPVCZE2L8B', '44YAIDY048'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'first_name', 'last_name', 'date_of_birth',
#        'company', 'email_address', 'address', 'country', 'country_code',
#        'phone_number', 'join_date', 'user_uuid'],
#       dtype='object')

# %%
clean_cc_df = df[df['country_code'].str.len() < 3]

# %%
clean_cc_df
# Out:
#        Unnamed: 0  index first_name last_name date_of_birth  \
# 0               0      0   Sigfried     Noack    1990-09-30
# 1               1      1        Guy     Allen    1940-12-01
# 2               2      2      Harry  Lawrence    1995-08-02
# 3               3      3     Darren   Hussain    1972-09-23
# 4               4      4      Garry     Stone    1952-12-20
# ...           ...    ...        ...       ...           ...
# 15315       15315  14913    Stephen   Jenkins    1943-08-09
# 15316       15316  14994    Stephen     Smith    1948-08-20
# 15317       15317  15012    Stephen  Losekann    1940-10-09
# 15318       15318  15269    Stephen    Rivera    1952-06-04
# 15319       15319   1249    Stephen    Duncan    1994-03-27
#
#                             company                 email_address  \
# 0                Heydrich Junitz KG             rudi79@winkler.de
# 1                           Fox Ltd  rhodesclifford@henderson.com
# ...

# %%
clean_cc_df['country_code'].unique()
# Out:
# array(['DE', 'GB', 'US'], dtype=object)

# %%
print(len(df))
print(len(clean_cc_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(len(df))
#       2 print(len(clean_cc_df))
#
# NameError: name 'df' is not defined

# %% [markdown]
# from databse_utils import DatabaseConnector
#
# connector = DatabaseConnector()
# upload_df = connector.upload_to_db(table_name)
#
# print(upload_df)
